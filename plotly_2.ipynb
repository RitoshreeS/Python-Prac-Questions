# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/My Drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import plotly.express as px
import plotly.figure_factory as ff

import plotly.graph_objects as go

# %%
df=pd.read_csv("StudentsPerformance[1].csv")
df
# Out:
#      gender race/ethnicity  ... reading score writing score
# 0    female        group B  ...            72            74
# 1    female        group C  ...            90            88
# 2    female        group B  ...            95            93
# 3      male        group A  ...            57            44
# 4      male        group C  ...            78            75
# ..      ...            ...  ...           ...           ...
# 995  female        group E  ...            99            95
# 996    male        group C  ...            55            55
# 997  female        group C  ...            71            65
# 998  female        group D  ...            78            77
# 999  female        group D  ...            86            86
#
# [1000 rows x 8 columns]

# %% [markdown]
# DENSITY PLOT

# %%
fig = ff.create_distplot(df, 'writing score',colors='gender')
fig.show()

# %%
fig = go.Figure(data =
    go.Contour(z=df,  colorscale='rainbow'
               ))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8ef388da-0179-44cb-a554-96c149a7113b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8ef388da-0179-44cb-a554-96c149a7113b")) {
#                     Plotly.newPlot(
#                         '8ef388da-0179-44cb-a554-96c149a7113b',
# ...

# %%
fig = px.scatter(df, x='race/ethnicity', y='writing score',
                 color='gender')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a7803761-adf2-4e97-a771-33c487a88f84" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a7803761-adf2-4e97-a771-33c487a88f84")) {
#                     Plotly.newPlot(
#                         'a7803761-adf2-4e97-a771-33c487a88f84',
# ...

# %% [markdown]
# 1. Group A
# Max score: Female-97
#            Male-2
# Min score: Female-45
#            Male-19
#
# 2. Group B
# Max Score: Female-96
#            Male-92
# Min Score: Female-23
#            Male-15
# 3. Group C
# Max Score: Female-100
#            Male-95
# Min Score: Female-10
#            Male-27
# 4. Group D
# Max Score: Female-100
#            Male-99
# Min Score: Female-32
#            Male-34
# 5. Group E
# Max Score: Female-97
#            Male-100
# Min Score: Female-38
#            Male-22
